# %%
import cv2 as cv
import time
import mediapipe as mp

# %%
capture = cv.VideoCapture(0) #1,2 numarası yazabilirsiniz.

# %%
width = int(capture.get(cv.CAP_PROP_FRAME_WIDTH))
height = int(capture.get(cv.CAP_PROP_FRAME_HEIGHT))

print(width)
print(height)
# Out:
# 640
# 480
